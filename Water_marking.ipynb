# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread('/content/Screenshot 2026-02-26 135502.png')
print("Before Water Mark:\n")
cv2_imshow(image)

# Add watermark text
cv2.putText(image,"WATERMARK",(150, 190),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),2)
print("After Water Mark:\n")
cv2_imshow(image)
# Out:
# Before Water Mark:
# <PIL.Image.Image image mode=RGB size=340x200>
# After Water Mark:
# <PIL.Image.Image image mode=RGB size=340x200>
